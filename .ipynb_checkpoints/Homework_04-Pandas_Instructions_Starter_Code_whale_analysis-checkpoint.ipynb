# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns = pd.read_csv("whale_returns.csv",index_col='Date', parse_dates=True)
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna()

# %%
whale_daily_R = whale_returns.pct_change()
whale_daily_R.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                  -2.762070           -1.650792
# 2015-03-05                   0.800968            0.257544
# 2015-03-06                  -2.968465           -1.876837
# 2015-03-09                  -1.073656           -2.182252
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                          NaN                     NaN
# 2015-03-04                     4.113646               -1.641381
# 2015-03-05                    -1.929234                0.596558
# 2015-03-06                    -4.601872               -2.947282
# 2015-03-09                    -1.688907               -0.873840

# %%
whale_daily_R.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
algo_returns = pd.read_csv("algo_returns.csv", index_col='Date', parse_dates=True)
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns = algo_returns.dropna()
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history = pd.read_csv("sp500_history.csv", index_col='Date', parse_dates=True)
sp500_history.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history["Close"] = sp500_history["Close"].str.replace("$", "")

# %%
sp500_history["Close"] = sp500_history["Close"].astype("float")

# %% [markdown]
# sp500_history.dtypes

# %%
sp500_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_history.describe(include='all')
# Out:
#              Close
# count  1649.000000
# mean   2154.279460
# std     402.122004
# min    1353.330000
# 25%    1880.050000
# 50%    2089.140000
# 75%    2473.450000
# max    2933.680000

# %%
# Calculate Daily Returns
sp500_history.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp500_returns = sp500_history.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_returns
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1649 rows x 1 columns]

# %%
sp500_returns.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
sp500_returns = sp500_returns.dropna()
sp500_returns
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
sp500_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns = sp500_returns.rename(columns={"Close": "S&P500"})
sp500_returns.head()
# Out:
#               S&P500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combine_returns = pd.concat([whale_returns, algo_returns, sp500_returns], axis=1, join='inner')
combine_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    S&P500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %%
combine_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios

# Calculate Individual Returns

# Whale Daily Return
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
whale_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
algo_daily_returns = algo_returns.pct_change()
algo_daily_returns.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05       NaN       NaN
# 2014-06-06 -0.542965 -0.376459
# 2014-06-09 -3.699288 -0.315757
# 2014-06-10 -1.879164 -1.129760
# 2014-06-11  0.080354  4.113963

# %%
algo_daily_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
# Concat all returns in new DataFrame all_returns
all_returns = pd.concat([whale_returns, algo_returns, sp500_returns], axis=1, join= "inner")
all_returns.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
# 2015-03-16                   0.007901            0.003583
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# ...

# %%
# Clean new data checking for null
all_returns.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# 2015-03-09                      False               False
# ...                               ...                 ...
# 2019-04-15                      False               False
# 2019-04-16                      False               False
# 2019-04-17                      False               False
# 2019-04-18                      False               False
# 2019-04-22                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-03                        False                   False   False
# 2015-03-04                        False                   False   False
# ...

# %%
# Drop all null's to prepare data for analysis
all_returns = all_returns.dropna()
all_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
all_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P500                         0
# dtype: int64

# %%
all_returns.duplicated().sum()
# Out:
# 0

# %%
all_returns = all_returns.drop_duplicates()

# %%
all_returns.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# Algo 1                         float64
# Algo 2                         float64
# S&P500                         float64
# dtype: object

# %%
# Plot cumulative returns
all_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
whale_returns.plot.box()
# Out:
# <AxesSubplot:>

# %%
algo_returns.plot.box()
# Out:
# <AxesSubplot:>

# %%
sp500_returns.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = all_returns.std()
daily_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P500                         0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
daily_std = daily_std.sort_values(ascending=False)
daily_std.head()

# Determine which portfolios are riskier than the S&P 500
## Berkshire has most risk vs S&P500
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# S&P500                         0.008587
# Algo 2                         0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std.head(10)
# Out:
# BERKSHIRE HATHAWAY INC         0.205079
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# S&P500                         0.136313
# Algo 2                         0.132413
# SOROS FUND MANAGEMENT LLC      0.125348
# Algo 1                         0.121006
# PAULSON & CO.INC.              0.111527
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

# Plot the rolling standard deviation

# %%
# Rolling Standart Deviation for Whale Returns

whale_returns.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Rolling Standart Deviation for Algo Returns

algo_returns.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Rolling Standart Deviation for S&P500 Returns

sp500_returns.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
price_correlation = all_returns.corr()
price_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P500                                        0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %%
import seaborn as sns

# %%
# Display de correlation matrix
sns.heatmap(price_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = all_returns['Algo 1'].cov(all_returns['S&P500'])
covariance
# Out:
# -2.223042551715527e-06

# %%
# Calculate variance of S&P500
variance = all_returns['S&P500'].var()
variance
# Out:
# 7.373467552840441e-05

# %%
# Computing beta for Algo 1
algo1_beta = covariance / variance
algo1_beta
# Out:
# -0.030149214542337766

# %%
# Plot beta trend
# Calculate 30-day rolling covariance of Algo1 vs. S&P 500 and plot the data
rolling_covariance = all_returns['Algo 1'].rolling(window=30).cov(all_returns['S&P500'])
rolling_covariance.plot(figsize=(20, 10), title='Rolling 30-Day Covariance of Algo 1 Returns vs. S&P500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Covariance of Algo 1 Returns vs. S&P500 Returns'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
sp500_returns.rolling(window=21).ewm()

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratio
sharp_ratio_data = pd.concat([whale_returns, algo_returns, sp500_returns, risk_free_rate], axis=1, join= "inner")
all_returns.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
# 2015-03-16                   0.007901            0.003583
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# ...

# %%
# Calculate Sharpe Ratio
# annualized avaerage return/ annualized standard deviation

sharpe_ratios = ((sharp_ratio_data.mean()-sharp_ratio_data['rf_rate'].mean()) * 252) / (sharp_ratio_data.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.190405
# PAULSON & CO.INC.             -0.710554
# TIGER GLOBAL MANAGEMENT LLC   -0.289644
# BERKSHIRE HATHAWAY INC         0.506336
# Algo 1                         1.138811
# Algo 2                         0.297259
# S&P500                        -0.779210
# rf_rate                        0.000000
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %%
## Based on the analisy it is conclusive that the Algoritmic strategies outperforms both the markets and the whales portfolio

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
AEGN_cp = pd.read_csv("AEGN.csv",index_col='Date', parse_dates=True)
AEGN_cp.head()
# Out:
#                      Close
# Date
# 2015-03-02 16:00:00  18.49
# 2015-03-03 16:00:00  18.31
# 2015-03-04 16:00:00  18.24
# 2015-03-05 16:00:00  17.98
# 2015-03-06 16:00:00  17.34

# %%
AEGN_cp = AEGN_cp.rename(columns={"Close": "AEGN"})
AEGN_cp.head()
# Out:
#                       AEGN
# Date
# 2015-03-02 16:00:00  18.49
# 2015-03-03 16:00:00  18.31
# 2015-03-04 16:00:00  18.24
# 2015-03-05 16:00:00  17.98
# 2015-03-06 16:00:00  17.34

# %%
# Reading data from 2nd stock
MMM_cp = pd.read_csv("MMM.csv",index_col='Date', parse_dates=True)
MMM_cp.head()
# Out:
#                       Close
# Date
# 2015-03-02 16:00:00  170.50
# 2015-03-03 16:00:00  168.27
# 2015-03-04 16:00:00  167.16
# 2015-03-05 16:00:00  167.57
# 2015-03-06 16:00:00  164.36

# %%
# Reading data from 3rd stock
NVDA_cp = pd.read_csv("NVDA.csv",index_col='Date', parse_dates=True)
NVDA_cp.head()
# Out:
#                      Close
# Date
# 2015-03-02 16:00:00  22.60
# 2015-03-03 16:00:00  22.18
# 2015-03-04 16:00:00  22.43
# 2015-03-05 16:00:00  22.86
# 2015-03-06 16:00:00  22.55

# %%
NVDA_cp = NVDA_cp.rename(columns={"Close": "NVDA"})
NVDA_cp.head()
# Out:
#                       NVDA
# Date
# 2015-03-02 16:00:00  22.60
# 2015-03-03 16:00:00  22.18
# 2015-03-04 16:00:00  22.43
# 2015-03-05 16:00:00  22.86
# 2015-03-06 16:00:00  22.55

# %%
MMM_cp = MMM_cp.rename(columns={"Close": "MMM"})
MMM_cp.head()
# Out:
#                         MMM
# Date
# 2015-03-02 16:00:00  170.50
# 2015-03-03 16:00:00  168.27
# 2015-03-04 16:00:00  167.16
# 2015-03-05 16:00:00  167.57
# 2015-03-06 16:00:00  164.36

# %%
# Reading data from 4rd stock
PYPL_cp = pd.read_csv("PYPL.csv",index_col='Date', parse_dates=True)
PYPL_cp.head()
# Out:
#                      Close
# Date
# 2015-07-06 16:00:00  36.71
# 2015-07-07 16:00:00  36.62
# 2015-07-08 16:00:00  34.70
# 2015-07-09 16:00:00  34.50
# 2015-07-10 16:00:00  34.69

# %%
PYPL_cp = PYPL_cp.rename(columns={"Close": "PYPL"})
PYPL_cp.head()
# Out:
#                       PYPL
# Date
# 2015-07-06 16:00:00  36.71
# 2015-07-07 16:00:00  36.62
# 2015-07-08 16:00:00  34.70
# 2015-07-09 16:00:00  34.50
# 2015-07-10 16:00:00  34.69

# %%
# Combine all stocks in a single DataFrame
bluepalm_cp = pd.concat([AEGN_cp, MMM_cp, NVDA_cp, PYPL_cp], axis=1, join= "inner")
bluepalm_cp.head(10)
# Out:
#                       AEGN     MMM   NVDA   PYPL
# Date
# 2015-07-06 16:00:00  18.81  155.08  20.17  36.71
# 2015-07-07 16:00:00  18.36  155.43  19.79  36.62
# 2015-07-08 16:00:00  17.71  152.71  19.65  34.70
# 2015-07-09 16:00:00  17.70  153.75  19.41  34.50
# 2015-07-10 16:00:00  17.91  154.95  19.75  34.69
# 2015-07-13 16:00:00  18.06  156.47  19.88  36.78
# 2015-07-14 16:00:00  18.45  156.78  19.89  36.93
# 2015-07-15 16:00:00  18.06  156.00  19.75  37.51
# 2015-07-16 16:00:00  18.09  157.17  20.19  38.63
# 2015-07-17 16:00:00  17.95  156.69  20.07  38.39

# %%
bluepalm_cp.index = bluepalm_cp.index.normalize()

# %%
bluepalm_cp.head()
# Out:
#              AEGN     MMM   NVDA   PYPL
# Date
# 2015-07-06  18.81  155.08  20.17  36.71
# 2015-07-07  18.36  155.43  19.79  36.62
# 2015-07-08  17.71  152.71  19.65  34.70
# 2015-07-09  17.70  153.75  19.41  34.50
# 2015-07-10  17.91  154.95  19.75  34.69

# %%
# Reorganize portfolio data by having a column per symbol
bluepalm_cp.head()
# Out:
#              AEGN     MMM   NVDA   PYPL
# Date
# 2015-07-06  18.81  155.08  20.17  36.71
# 2015-07-07  18.36  155.43  19.79  36.62
# 2015-07-08  17.71  152.71  19.65  34.70
# 2015-07-09  17.70  153.75  19.41  34.50
# 2015-07-10  17.91  154.95  19.75  34.69

# %%
bluepalm_cp.isnull()
# Out:
#              AEGN    MMM   NVDA   PYPL
# Date
# 2015-07-06  False  False  False  False
# 2015-07-07  False  False  False  False
# 2015-07-08  False  False  False  False
# 2015-07-09  False  False  False  False
# 2015-07-10  False  False  False  False
# ...           ...    ...    ...    ...
# 2020-12-23  False  False  False  False
# 2020-12-24  False  False  False  False
# 2020-12-28  False  False  False  False
# 2020-12-29  False  False  False  False
# 2020-12-30  False  False  False  False
#
# [1384 rows x 4 columns]

# %%
bluepalm_cp.dropna()
# Out:
#              AEGN     MMM    NVDA    PYPL
# Date
# 2015-07-06  18.81  155.08   20.17   36.71
# 2015-07-07  18.36  155.43   19.79   36.62
# 2015-07-08  17.71  152.71   19.65   34.70
# 2015-07-09  17.70  153.75   19.41   34.50
# 2015-07-10  17.91  154.95   19.75   34.69
# ...           ...     ...     ...     ...
# 2020-12-23  18.92  173.99  520.37  239.44
# 2020-12-24  19.25  174.52  519.75  238.64
# 2020-12-28  19.20  174.71  516.00  235.73
# 2020-12-29  18.80  173.85  517.73  231.03
# 2020-12-30  18.97  174.11  525.83  231.51
#
# [1384 rows x 4 columns]

# %%
# Calculate daily returns
AEGN_daily_returns = AEGN_cp.pct_change()
AEGN_daily_returns.head()
# Out:
#                          AEGN
# Date
# 2015-03-02 16:00:00       NaN
# 2015-03-03 16:00:00 -0.009735
# 2015-03-04 16:00:00 -0.003823
# 2015-03-05 16:00:00 -0.014254
# 2015-03-06 16:00:00 -0.035595

# %%
MMM_daily_returns = MMM_cp.pct_change()
MMM_daily_returns.head()
# Out:
#                           MMM
# Date
# 2015-03-02 16:00:00       NaN
# 2015-03-03 16:00:00 -0.013079
# 2015-03-04 16:00:00 -0.006597
# 2015-03-05 16:00:00  0.002453
# 2015-03-06 16:00:00 -0.019156

# %%
NVDA_daily_returns = NVDA_cp.pct_change()
NVDA_daily_returns.head()
# Out:
#                          NVDA
# Date
# 2015-03-02 16:00:00       NaN
# 2015-03-03 16:00:00 -0.018584
# 2015-03-04 16:00:00  0.011271
# 2015-03-05 16:00:00  0.019171
# 2015-03-06 16:00:00 -0.013561

# %%
PYPL_daily_returns = PYPL_cp.pct_change()
PYPL_daily_returns.head()
# Out:
#                          PYPL
# Date
# 2015-07-06 16:00:00       NaN
# 2015-07-07 16:00:00 -0.002452
# 2015-07-08 16:00:00 -0.052430
# 2015-07-09 16:00:00 -0.005764
# 2015-07-10 16:00:00  0.005507

# %%
# Combine all Daily Returns in one DataFrame
BPM_daily_returns = pd.concat([AEGN_daily_returns, MMM_daily_returns, NVDA_daily_returns, PYPL_daily_returns], axis=1, join='inner')
BPM_daily_returns.head()
# Out:
#                          AEGN       MMM      NVDA      PYPL
# Date
# 2015-07-06 16:00:00  0.005882 -0.001931 -0.012243       NaN
# 2015-07-07 16:00:00 -0.023923  0.002257 -0.018840 -0.002452
# 2015-07-08 16:00:00 -0.035403 -0.017500 -0.007074 -0.052430
# 2015-07-09 16:00:00 -0.000565  0.006810 -0.012214 -0.005764
# 2015-07-10 16:00:00  0.011864  0.007805  0.017517  0.005507

# %%
BPM_daily_returns.index = BPM_daily_returns.index.normalize()

# %%
# Drop NAs
BPM_daily_returns.dropna()
# Out:
#                 AEGN       MMM      NVDA      PYPL
# Date
# 2015-07-07 -0.023923  0.002257 -0.018840 -0.002452
# 2015-07-08 -0.035403 -0.017500 -0.007074 -0.052430
# 2015-07-09 -0.000565  0.006810 -0.012214 -0.005764
# 2015-07-10  0.011864  0.007805  0.017517  0.005507
# 2015-07-13  0.008375  0.009810  0.006582  0.060248
# ...              ...       ...       ...       ...
# 2020-12-23  0.021598 -0.004520 -0.020259 -0.016633
# 2020-12-24  0.017442  0.003046 -0.001191 -0.003341
# 2020-12-28 -0.002597  0.001089 -0.007215 -0.012194
# 2020-12-29 -0.020833 -0.004922  0.003353 -0.019938
# 2020-12-30  0.009043  0.001496  0.015645  0.002078
#
# [1383 rows x 4 columns]

# %%
BPM_daily_returns
# Out:
#                 AEGN       MMM      NVDA      PYPL
# Date
# 2015-07-06  0.005882 -0.001931 -0.012243       NaN
# 2015-07-07 -0.023923  0.002257 -0.018840 -0.002452
# 2015-07-08 -0.035403 -0.017500 -0.007074 -0.052430
# 2015-07-09 -0.000565  0.006810 -0.012214 -0.005764
# 2015-07-10  0.011864  0.007805  0.017517  0.005507
# ...              ...       ...       ...       ...
# 2020-12-23  0.021598 -0.004520 -0.020259 -0.016633
# 2020-12-24  0.017442  0.003046 -0.001191 -0.003341
# 2020-12-28 -0.002597  0.001089 -0.007215 -0.012194
# 2020-12-29 -0.020833 -0.004922  0.003353 -0.019938
# 2020-12-30  0.009043  0.001496  0.015645  0.002078
#
# [1384 rows x 4 columns]

# %%
# Display sample data
BPM_daily_returns.sample
# Out:
# <bound method NDFrame.sample of                 AEGN       MMM      NVDA      PYPL
# Date
# 2015-07-06  0.005882 -0.001931 -0.012243       NaN
# 2015-07-07 -0.023923  0.002257 -0.018840 -0.002452
# 2015-07-08 -0.035403 -0.017500 -0.007074 -0.052430
# 2015-07-09 -0.000565  0.006810 -0.012214 -0.005764
# 2015-07-10  0.011864  0.007805  0.017517  0.005507
# ...              ...       ...       ...       ...
# 2020-12-23  0.021598 -0.004520 -0.020259 -0.016633
# 2020-12-24  0.017442  0.003046 -0.001191 -0.003341
# 2020-12-28 -0.002597  0.001089 -0.007215 -0.012194
# 2020-12-29 -0.020833 -0.004922  0.003353 -0.019938
# 2020-12-30  0.009043  0.001496  0.015645  0.002078
#
# [1384 rows x 4 columns]>

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/4, 1/4, 1/4, 1/4]

# Calculate portfolio return
BPM_portfolio_returns = BPM_daily_returns.dot(weights)

# Display sample data
BPM_portfolio_returns.head()
# Out:
# Date
# 2015-07-06         NaN
# 2015-07-07   -0.010740
# 2015-07-08   -0.028102
# 2015-07-09   -0.002933
# 2015-07-10    0.010673
# dtype: float64

# %%
BPM_portfolio_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
JOIN_daily_returns = pd.concat([all_returns, BPM_daily_returns, risk_free_rate], axis=1)
JOIN_daily_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN       NaN
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2    S&P500  AEGN  MMM  NVDA  PYPL   rf_rate
# Date
# 2015-03-02       NaN       NaN   NaN  NaN   NaN   NaN  0.000002
# ...

# %%
JOIN_daily_returns.sort_values("Date", ascending=False)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2020-12-30                        NaN                 NaN
# 2020-12-29                        NaN                 NaN
# 2020-12-28                        NaN                 NaN
# 2020-12-24                        NaN                 NaN
# 2020-12-23                        NaN                 NaN
# ...                               ...                 ...
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-05                   0.004016            0.004076
# 2015-03-04                   0.002230            0.003241
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-02                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2020-12-30                          NaN                     NaN       NaN
# 2020-12-29                          NaN                     NaN       NaN
# ...

# %%
JOIN_daily_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2020-12-23                        NaN                 NaN
# 2020-12-24                        NaN                 NaN
# 2020-12-28                        NaN                 NaN
# 2020-12-29                        NaN                 NaN
# 2020-12-30                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN       NaN
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaN)
JOIN_daily_returns.dropna()
JOIN_daily_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN       NaN
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2    S&P500  AEGN  MMM  NVDA  PYPL   rf_rate
# Date
# 2015-03-02       NaN       NaN   NaN  NaN   NaN   NaN  0.000002
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate Daily STD
custom_daily_std = JOIN_daily_returns.std().sort_values(ascending=False)
custom_daily_std.head(10)
# Out:
# NVDA                           0.029457
# AEGN                           0.026349
# PYPL                           0.021571
# MMM                            0.015219
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# S&P500                         0.008587
# Algo 2                         0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 1                         0.007623
# dtype: float64

# %%
custom_daily_std.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Calculate the annualized standard deviation (252 trading days)
new_annualized_std = custom_daily_std * np.sqrt(252)
new_annualized_std.head(10)
# Out:
# NVDA                           0.467623
# AEGN                           0.418272
# PYPL                           0.342436
# MMM                            0.241593
# BERKSHIRE HATHAWAY INC         0.205079
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# S&P500                         0.136313
# Algo 2                         0.132413
# SOROS FUND MANAGEMENT LLC      0.125348
# Algo 1                         0.121006
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
JOIN_daily_returns.rolling(window=21).std()
# Plot rolling standard deviation
JOIN_daily_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
BPM_correlation = JOIN_daily_returns.corr()
BPM_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P500                                        0.000574            0.013549
# AEGN                                          0.414054            0.334301
# MMM                                           0.544808            0.394012
# NVDA                                          0.478872            0.325693
# PYPL                                          0.537785            0.396944
# ...

# %%
BPM_correlation.dropna()
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P500                                        0.000574            0.013549
# AEGN                                          0.414054            0.334301
# MMM                                           0.544808            0.394012
# NVDA                                          0.478872            0.325693
# PYPL                                          0.537785            0.396944
# ...

# %%
sns.heatmap(BPM_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
BPM_covariance = JOIN_daily_returns['PYPL'].cov(JOIN_daily_returns['S&P500'])
BPM_covariance
# Out:
# -5.059961154935741e-06

# %%
# Calculate variance of all daily returns of PYPL vs. S&P 500
BPM_variance = BPM_daily_returns['PYPL'].var()
BPM_variance
# Out:
# 0.0004653275250088394

# %%
# Calculate beta of all daily returns of PYPL
PYPL_beta = BPM_covariance / BPM_variance
PYPL_beta
# Out:
# -0.010873977753281673

# %%
# Calculate 60 Day Rolling Covarience PYPL
BPM_rolling_covariance = JOIN_daily_returns['PYPL'].rolling(window=60).cov(JOIN_daily_returns['S&P500'])
BPM_rolling_covariance.plot(figsize=(20, 10), title='Rolling 60-Day Covariance of PYPL Returns vs. S&P500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Covariance of PYPL Returns vs. S&P500 Returns'}, xlabel='Date'>

# %%
# Calculate 60-day rolling variance of PYPL vs. S&P 500 and plot the data
BPM_rolling_variance = JOIN_daily_returns['S&P500'].rolling(window=60).var()
BPM_rolling_variance.plot(figsize=(20, 10), title='Rolling 60-Day Variance of S&P 500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Variance of S&P 500 Returns'}, xlabel='Date'>

# %%
# Calculate 60-day rolling beta of PYPL and plot the data
BPM_rolling_beta = BPM_rolling_covariance / BPM_rolling_variance
BPM_rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of PYPL')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of PYPL'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios with a max of 10% risk free rate
# Calculate Sharpe Ratio
# annualized avaerage return/ annualized standard deviation
BPM_sharpe_ratios = ((JOIN_daily_returns.mean()-JOIN_daily_returns['rf_rate'].mean()) * 252) / (JOIN_daily_returns.std() * np.sqrt(252))
BPM_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.124644
# PAULSON & CO.INC.             -0.736719
# TIGER GLOBAL MANAGEMENT LLC   -0.288330
# BERKSHIRE HATHAWAY INC         0.473344
# Algo 1                         1.143509
# Algo 2                         0.277730
# S&P500                        -0.719276
# AEGN                           0.152233
# MMM                            0.094158
# NVDA                           1.439476
# PYPL                           1.071118
# rf_rate                        0.000000
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# Plot sharpe ratios
BPM_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

## The higher the sharpe ratio, the greater the excess reward, which means a smarter investment.
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
""" Based on the Share Ration analysis, it is my conulsion that, the current investment portfolios need to be revised to include the following stocks, to positively affec the returns for Harold's company. I suggest, the porfolio be revised to include, Algo 1, NVDA, BRK and PYPL.
